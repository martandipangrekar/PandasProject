# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import numpy
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\mahes\\OneDrive\\Desktop\\Pandas Project\\CarPrice.csv")

# %%
df
# Out:
#      car_ID                   CarName fueltype  doornumber      carbody  \
# 0         1        alfa-romero giulia      gas           2  convertible
# 1         2       alfa-romero stelvio      gas           2  convertible
# 2         3  alfa-romero Quadrifoglio      gas           2    hatchback
# 3         4               audi 100 ls      gas           4        sedan
# 4         5                audi 100ls      gas           4        sedan
# ..      ...                       ...      ...         ...          ...
# 200     201           volvo 145e (sw)      gas           4        sedan
# 201     202               volvo 144ea      gas           4        sedan
# 202     203               volvo 244dl      gas           4        sedan
# 203     204                 volvo 246   diesel           4        sedan
# 204     205               volvo 264gl      gas           4        sedan
#
#     drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# ...

# %%
df.head()
# Out:
#    car_ID                   CarName fueltype  doornumber      carbody  \
# 0       1        alfa-romero giulia      gas           2  convertible
# 1       2       alfa-romero stelvio      gas           2  convertible
# 2       3  alfa-romero Quadrifoglio      gas           2    hatchback
# 3       4               audi 100 ls      gas           4        sedan
# 4       5                audi 100ls      gas           4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype  cylindernumber  enginesize fuelsystem  horsepower  \
# ...

# %%
df.tail()
# Out:
#      car_ID          CarName fueltype  doornumber carbody drivewheel  \
# 200     201  volvo 145e (sw)      gas           4   sedan        rwd
# 201     202      volvo 144ea      gas           4   sedan        rwd
# 202     203      volvo 244dl      gas           4   sedan        rwd
# 203     204        volvo 246   diesel           4   sedan        rwd
# 204     205      volvo 264gl      gas           4   sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 200          front      109.1      188.8      68.9       55.5        2952
# 201          front      109.1      188.8      68.8       55.5        3049
# 202          front      109.1      188.8      68.9       55.5        3012
# 203          front      109.1      188.8      68.9       55.5        3217
# 204          front      109.1      188.8      68.9       55.5        3062
#
#     enginetype  cylindernumber  enginesize fuelsystem  horsepower  citympg  \
# ...

# %%
res=df['car_ID']

# %%
df.set_index("car_ID", inplace = True)

# %%
ID_result=df.loc[150]

# %%
ID_result
# Out:
# doornumber            4
# carbody           wagon
# drivewheel          4wd
# enginelocation    front
# wheelbase          96.9
# carlength         173.6
# carwidth           65.4
# carheight          54.9
# curbweight         2650
# enginetype         ohcf
# cylindernumber        4
# enginesize          108
# fuelsystem         mpfi
# horsepower          111
# citympg              23
# highwaympg           23
# price             11694
# Name: 150, dtype: object

# %%
df.set_index("cylindernumber", inplace = True)

# %%
CylinderNO=df.loc[6]

# %%
CylinderNO
# Out:
#                 doornumber      carbody drivewheel enginelocation  wheelbase  \
# cylindernumber
# 6                        2    hatchback        rwd          front       94.5
# 6                        2        sedan        rwd          front      101.2
# 6                        4        sedan        rwd          front      101.2
# 6                        4        sedan        rwd          front      103.5
# 6                        4        sedan        rwd          front      103.5
# 6                        2        sedan        rwd          front      103.5
# 6                        4        sedan        rwd          front      110.0
# 6                        4        sedan        rwd          front      113.0
# 6                        4        sedan        rwd          front      113.0
# 6                        4        sedan        fwd          front      100.4
# 6                        4        wagon        fwd          front      100.4
# ...

# %%
df.set_index("carbody", inplace = True)

# %%
Body=df.loc['sedan' ]

# %%
Body
# Out:
#          doornumber drivewheel enginelocation  wheelbase  carlength  carwidth  \
# carbody
# sedan             4        fwd          front       99.8      176.6      66.2
# sedan             4        4wd          front       99.4      176.6      66.4
# sedan             2        fwd          front       99.8      177.3      66.3
# sedan             4        fwd          front      105.8      192.7      71.4
# sedan             4        fwd          front      105.8      192.7      71.4
# ...             ...        ...            ...        ...        ...       ...
# sedan             4        rwd          front      109.1      188.8      68.9
# sedan             4        rwd          front      109.1      188.8      68.8
# sedan             4        rwd          front      109.1      188.8      68.9
# sedan             4        rwd          front      109.1      188.8      68.9
# sedan             4        rwd          front      109.1      188.8      68.9
#
# ...

# %%
Alpha=df.sort_index(key=None)

# %%
Alpha
# Out:
#              doornumber drivewheel enginelocation  wheelbase  carlength  \
# carbody
# convertible           2        rwd          front       88.6      168.8
# convertible           2        rwd          front       96.6      180.3
# convertible           2        fwd          front       94.5      159.3
# convertible           2        rwd           rear       89.5      168.9
# convertible           2        rwd          front       98.4      176.2
# ...                 ...        ...            ...        ...        ...
# wagon                 4        fwd          front       95.7      169.7
# wagon                 4        4wd          front       95.7      169.7
# wagon                 4        4wd          front       95.7      169.7
# wagon                 4        rwd          front      114.2      198.9
# wagon                 4        fwd          front      100.4      184.6
#
#              carwidth  carheight  curbweight enginetype  enginesize  \
# carbody
# ...
